# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanu27/SKIRPSI/blob/main/Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
# Try reading with 'latin-1' encoding and error_bad_lines=False to skip problematic lines
df = pd.read_csv('/content/dataset_tiktok-comments-scraper_2024-10-28_09-38-45-381.csv',
                 encoding='latin-1',
                 on_bad_lines='skip')  # or on_bad_lines='warn' to get warnings
# If 'latin-1' doesn't work, you may need to experiment with other encodings
# such as 'iso-8859-1', 'cp1252', etc.

df
# Out:
#                                                text
# 0         ANJAY22: â¨Goods Gameplay Everytimee,â¨
# 1                @ANJAY22. Congratulations broo.â¨
# 2                @AnJay22 â¨Thenext Masterclassâ¨
# 3                   @ANJAY22. TheNext SuperStarsâ¨
# 4                                      sty blunder
# ...                                             ...
# 2123  nanti jam 5 aku udh sampai ke stadion Qingdao
# 2124                                 yok bisa 3poin
# 2125                                 3-0 ayo Garuda
# 2126                           yo bismillah 3 point
# 2127                   4 0 indo menang gw botak min
#
# [2128 rows x 1 columns]

# %%
import pandas as pd
import re

# Fungsi untuk menghapus emoji, karakter non-Latin, dan angka dari teks
def clean_text(text):
    emoji_pattern = re.compile(
        "["u"\U0001F600-\U0001F64F" u"\U0001F300-\U0001F5FF"
        u"\U0001F680-\U0001F6FF" u"\U0001F700-\U0001F77F"
        u"\U0001F780-\U0001F7FF" u"\U0001F800-\U0001F8FF"
        u"\U0001F900-\U0001F9FF" u"\U0001FA00-\U0001FA6F"
        u"\U0001FA70-\U0001FAFF" u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251" "]+", flags=re.UNICODE
    )
    text = emoji_pattern.sub('', text)             # Hapus emoji
    text = re.sub("[^\u0000-\u007F]+", '', text)   # Hapus karakter non-Latin
    text = re.sub(r'\d+', '', text)                # Hapus angka
    return text

# Membaca data dari file CSV
data = pd.read_csv("/content/dataset_tiktok-comments-scraper_2024-10-28_09-38-45-381.csv", encoding='latin-1')
data["text"] = data["text"].astype(str)

# Membersihkan data dengan fungsi clean_text, menghapus simbol, dan mengubah menjadi huruf kecil
data["text"] = data["text"].apply(clean_text)
data["text"] = data["text"].str.replace(r'[^\w\s]', '', regex=True).str.lower()

# Menghapus baris kosong
data = data[data["text"].str.strip().astype(bool)]

# Menampilkan data
print(data.to_markdown(index=False, numalign="left", stralign="left"))

# Menyimpan data kembali ke file CSV
data.to_csv("data_Cleaning.csv", index=False)

# %%
import pandas as pd

# File path
LEXICON_FILE_PATH = '/content/sentiwords_id.txt'

# Load lexicon from file
def load_lexicon(file_path):
    lexicon = {}
    with open(file_path, 'r') as file:
        for line in file:
            word, score = line.strip().split(':')
            lexicon[word] = int(score)
    return lexicon

# Tokenize input text
def tokenize(text):
    return text.lower().split()

# Calculate sentiment score
def calculate_sentiment(text, lexicon):
    words = tokenize(text)
    sentiment_score = 0
    for word in words:
        if word in lexicon:
            sentiment_score += lexicon[word]
    return sentiment_score

# Classify sentiment based on score
def classify_sentiment(score):
    if score > 0:
        return "Positive"
    elif score < 0:
        return "Negative"
    else:
        return "Neutral"

# Main function for sentiment analysis
def sentiment_analysis(text):
    lexicon = load_lexicon(LEXICON_FILE_PATH)
    score = calculate_sentiment(text, lexicon)
    sentiment = classify_sentiment(score)
    return sentiment, score

# Example usage
data = pd.read_csv("/content/data_Cleaning.csv")

# Assuming there's a column named 'text' containing the text data
data['Sentiment'], data['Score'] = zip(*data['text'].apply(sentiment_analysis))

# Print results
print(data[['text', 'Sentiment','Score']])
data.to_csv('data_with_sentiment.csv', index=False) # Save results_df instead of data
# Out:
#                                               text Sentiment  Score
# 0                  anjay goods gameplay everytimee   Neutral      0
# 1                       anjay congratulations broo   Neutral      0
# 2                        anjay thenext masterclass   Neutral      0
# 3                         anjay thenext superstars   Neutral      0
# 4                                     sty blunder   Negative     -3
# ...                                            ...       ...    ...
# 2074  nanti jam  aku udh sampai ke stadion qingdao   Neutral      0
# 2075                                 yok bisa poin   Neutral      0
# 2076                                    ayo garuda   Neutral      0
# 2077                           yo bismillah  point   Neutral      0
# 2078                      indo menang gw botak min  Positive      4
#
# [2079 rows x 3 columns]

# %%
# prompt: berikan visualisasi histgram kolom sentimen

import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'data' and has a column named 'Sentiment'
# Replace 'data' with the actual name of your DataFrame if it's different

# Count the occurrences of each sentiment
sentiment_counts = data['Sentiment'].value_counts()

# Create a histogram
plt.figure(figsize=(8, 6))
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.xlabel('Sentiment')
plt.ylabel('Number of Comments')
plt.title('Histogram of Sentiment')
plt.show()

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from collections import Counter
import numpy as np

# Baca dataset
data = pd.read_csv("/content/data_with_sentiment.csv")

# Pisahkan data menjadi teks dan label
texts = data['text']  # Ganti 'text_column' dengan nama kolom teks pada dataset
labels = data['Sentiment']  # Ganti 'sentiment_column' dengan nama kolom label sentimen pada dataset

# Preprocessing: Fungsi untuk menghasilkan trigram
def generate_trigrams(text):
    words = text.split()  # Pisahkan teks menjadi kata-kata
    trigrams = [' '.join(words[i:i+3]) for i in range(len(words) - 2)]
    return trigrams

# Ekstraksi fitur trigram dari teks
def extract_features(texts):
    trigram_list = []
    for text in texts:
        trigrams = generate_trigrams(text)
        trigram_list.extend(trigrams)

    # Buat kamus semua trigram unik
    unique_trigrams = list(set(trigram_list))
    trigram_index = {trigram: i for i, trigram in enumerate(unique_trigrams)}

    # Representasikan teks sebagai vektor trigram
    features = []
    for text in texts:
        text_trigrams = generate_trigrams(text)
        trigram_counts = Counter(text_trigrams)
        feature_vector = np.zeros(len(unique_trigrams))

        for trigram, count in trigram_counts.items():
            if trigram in trigram_index:
                feature_vector[trigram_index[trigram]] = count
        features.append(feature_vector)

    return np.array(features), unique_trigrams

# Ekstraksi fitur trigram manual
X, trigram_features = extract_features(texts)

# Split data menjadi data pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

# Model Decision Tree
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Prediksi dan evaluasi
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6418269230769231
#               precision    recall  f1-score   support
#
#     Negative       0.50      0.02      0.04        87
#      Neutral       0.64      1.00      0.78       262
#     Positive       1.00      0.04      0.09        67
#
#     accuracy                           0.64       416
#    macro avg       0.71      0.36      0.30       416
# weighted avg       0.67      0.64      0.51       416

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from collections import Counter
import numpy as np

# Baca dataset
data = pd.read_csv("/content/data_with_sentiment.csv")

# Pisahkan data menjadi teks dan label
texts = data['text']  # Ganti 'text_column' dengan nama kolom teks pada dataset
labels = data['Sentiment']  # Ganti 'sentiment_column' dengan nama kolom label sentimen pada dataset

# Fungsi untuk menghasilkan n-grams
def generate_ngrams(text, n=3):
    words = text.split()
    ngrams = [' '.join(words[i:i+n]) for i in range(len(words) - n + 1)]
    return ngrams

# Ekstraksi fitur n-gram dari teks
def extract_features(texts, n=3):
    ngram_list = []
    for text in texts:
        ngrams = generate_ngrams(text, n=n)
        ngram_list.extend(ngrams)

    # Buat kamus semua n-gram unik
    unique_ngrams = list(set(ngram_list))
    ngram_index = {ngram: i for i, ngram in enumerate(unique_ngrams)}

    # Representasikan teks sebagai vektor n-gram
    features = []
    for text in texts:
        text_ngrams = generate_ngrams(text, n=n)
        ngram_counts = Counter(text_ngrams)
        feature_vector = np.zeros(len(unique_ngrams))

        for ngram, count in ngram_counts.items():
            if ngram in ngram_index:
                feature_vector[ngram_index[ngram]] = count
        features.append(feature_vector)

    return np.array(features), unique_ngrams

# Ekstraksi fitur n-gram manual (ubah n sesuai kebutuhan, misalnya n=2 untuk bigram, n=3 untuk trigram)
n = 1  # Ganti dengan nilai n yang diinginkan
X, ngram_features = extract_features(texts, n=n)

# Split data menjadi data pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

# Model Decision Tree
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Prediksi dan evaluasi
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8629807692307693
#               precision    recall  f1-score   support
#
#     Negative       0.87      0.82      0.84        87
#      Neutral       0.89      0.93      0.91       262
#     Positive       0.72      0.66      0.69        67
#
#     accuracy                           0.86       416
#    macro avg       0.83      0.80      0.81       416
# weighted avg       0.86      0.86      0.86       416

# %%
ngram_features
# Out:
# ['tindakan',
#  'gimaanaaaa',
#  'ngubahlime',
#  'ahh',
#  'penerus',
#  'kala',
#  'jawb',
#  'anjeng',
#  'gathel',
#  'sial',
#  'hahahah',
#  'esok',
#  'bgumpan',
#  'bahwa',
#  'its',
#  'repot',
#  'tundukan',
#  'berjuang',
#  'mandang',
#  'merubah',
#  'maupun',
#  'matanya',
#  'seumur',
#  'verdonk',
#  'engkau',
#  'sering',
#  'ngehujatpadahal',
#  'gaib',
#  'kirim',
#  'aseli',
#  'ckp',
#  'jepang',
#  'wahai',
#  'rabbb',
#  'klub',
#  'pret',
#  'jay',
#  'bjirrr',
#  'ragnar',
#  'apalgi',
#  'da',
#  'bangke',
#  'kabar',
#  'namanya',
#  'ngeremehin',
#  'jerman',
#  'nyaa',
#  'kehilangan',
#  'anyinggg',
#  'rezekinya',
#  'jidat',
#  'all',
#  'terima',
#  'alasan',
#  'real',
#  'gmn',
#  'nii',
#  'consider',
#  'kudu',
#  'percaya',
#  'satupun',
#  'lane',
#  'jujur',
#  'jauhan',
#  'ngaruh',
#  'para',
#  'kn',
#  'mrka',
#  'diaasnawi',
#  'kiper',
#  'lama',
#  'anthem',
#  'ku',
#  'sring',
#  'wkwkwkw',
#  'goblok',
#  'pintar',
#  'will',
#  'parley',
#  'hilang',
#  'cukup',
#  'iyakkk',
#  'lunak',
#  'pertandingan',
#  'nyusahin',
#  'barusan',
#  'gassss',
#  'berhenti',
#  'susul',
#  'kwkwkw',
#  'bukan',
#  'gerbang',
#  'kaa',
#  'waktuny',
#  'injury',
#  'guna',
#  'sesuai',
#  'sakitnya',
#  'hujat',
#  'waktu',
#  'cinta',
#  'gatel',
#  'emosinya',
#  'sang',
#  'egois',
#  'sakitdia',
#  'rame',
#  'mungkin',
#  'banggaaa',
#  'dipecat',
#  'iyy',
#  'tepat',
#  'china',
#  'greduk',
#  'singkat',
#  'temok',
#  'tonton',
#  'daerah',
#  'febi',
#  'jamaah',
#  'gips',
#  'emoji',
#  'grub',
#  'x',
#  'takdirnya',
#  'ayam',
#  'hoh',
#  'penyerangan',
#  'doanya',
#  'skli',
#  'attainable',
#  'makan',
#  'nunduk',
#  'ketertinggalan',
#  'bloko',
#  'kata',
#  'gilakk',
#  'hatrick',
#  'om',
#  'nafas',
#  'ditinggal',
#  'allahhhhh',
#  'bahasa',
#  'cepet',
#  'fomo',
#  'nyesek',
#  'skor',
#  'build',
#  'bolagx',
#  'man',
#  'bentuk',
#  'santaiminggu',
#  'rafa',
#  'pure',
#  'yudisum',
#  'timcoba',
#  'bolo',
#  'bikim',
#  'melebihkan',
#  'turu',
#  'nobar',
#  'punya',
#  'dimana',
#  'tidak',
#  'wheras',
#  'mulai',
#  'ksong',
#  'kene',
#  'semprit',
#  'ubah',
#  'setulus',
#  'i',
#  'allin',
#  'bcot',
#  'pertahanan',
#  'posisi',
#  'saqeen',
#  'lho',
#  'sabar',
#  'bklan',
#  'boneka',
#  'ngajarnya',
#  'syen',
#  'kenpa',
#  'eh',
#  'nemu',
#  'round',
#  'syilit',
#  'soalnya',
#  'mah',
#  'tutor',
#  'jauh',
#  'komenya',
#  'mdhan',
#  'corner',
#  'tetep',
#  'maklumm',
#  'asyuu',
#  'curangin',
#  'gengs',
#  'baned',
#  'al',
#  'klok',
#  'siap',
#  'ngk',
#  'postingan',
#  'keras',
#  'remeh',
#  'cooo',
#  'tentu',
#  'shin',
#  'pendukung',
#  'sejauh',
#  'engk',
#  'jembut',
#  'sikat',
#  'doa',
#  'banh',
#  'cepat',
#  'lewatt',
#  'indonesians',
#  'woy',
#  'merantau',
#  'adalah',
#  'panggil',
#  'anjayyyyyyuyumainkan',
#  'apaan',
#  'finishing',
#  'hokky',
#  'renggut',
#  'segala',
#  'pisan',
#  'kaga',
#  'kunjung',
#  'dribelity',
#  'duh',
#  'rehatkan',
#  'serang',
#  'doaankkk',
#  'kek',
#  'jam',
#  'suki',
#  'z',
#  'lohhh',
#  'jir',
#  'mlm',
#  'data',
#  'pemain',
#  'faktaa',
#  'sayang',
#  'aturannya',
#  'blundernya',
#  'mulu',
#  'hahahahahaha',
#  'bang',
#  'lapor',
#  'into',
#  'cobaa',
#  'kamu',
#  'between',
#  'ael',
#  'tololll',
#  'uji',
#  'on',
#  'prediksi',
#  'bunuhbunuh',
#  'wait',
#  'pngennya',
#  'murni',
#  'uu',
#  'selamanya',
#  'saling',
#  'yng',
#  'tutup',
#  'tetangga',
#  'main',
#  'hasil',
#  'lngsng',
#  'bayar',
#  'pakai',
#  'segawon',
#  'dulu',
#  'berikutnya',
#  'bener',
#  'cederah',
#  'jawab',
#  'tersiksa',
#  'bt',
#  'se',
#  'nk',
#  'bkin',
#  'tegakkan',
#  'sepakbola',
#  'hadehh',
#  'selama',
#  'makasih',
#  'dluan',
#  'ne',
#  'menjatuhkan',
#  'permudah',
#  'pinalti',
#  'diotak',
#  'dongs',
#  'skil',
#  'kritik',
#  'cup',
#  'hal',
#  'imbang',
#  'curangg',
#  'pncen',
#  'yang',
#  'rafaeeeellllllll',
#  'trllalu',
#  'membalikan',
#  'kalahin',
#  'silahkan',
#  'anyng',
#  'layak',
#  'goods',
#  'jg',
#  'terciptanya',
#  'susahnya',
#  'sty',
#  'bolos',
#  'jumat',
#  'sayangnya',
#  'gilak',
#  'rcti',
#  'jato',
#  'stadion',
#  'capten',
#  'kelihatan',
#  'dinding',
#  'yok',
#  'dijajah',
#  'copy',
#  'keluarganya',
#  'was',
#  'allah',
#  'gilaaa',
#  'boloo',
#  'nyiarin',
#  'jepangsama',
#  'oon',
#  'bermain',
#  'doang',
#  'malaydes',
#  'jugakalo',
#  'aff',
#  'aus',
#  'liup',
#  'resiko',
#  'perpanjang',
#  'pen',
#  'aj',
#  'ngapainnn',
#  'passinggamungkin',
#  'tpi',
#  'katain',
#  'kerasa',
#  'nyengir',
#  'jan',
#  'baarik',
#  'keberuntungan',
#  'awokwokk',
#  'profesional',
#  'taikkk',
#  'diaspora',
#  'temukan',
#  'ketawa',
#  'bujang',
#  'diskualifikasi',
#  'krusial',
#  'tuntut',
#  'membuat',
#  'dibwh',
#  'ernando',
#  'gaaaaakkkkkk',
#  'hitung',
#  'hidup',
#  'suara',
#  'harus',
#  'ajg',
#  'golll',
#  'the',
#  'hrsnya',
#  'pilinggkuu',
#  'latihan',
#  'mari',
#  'keliatann',
#  'tmbahin',
#  'negara',
#  'ngapa',
#  'buktikan',
#  'dendam',
#  'stop',
#  'wak',
#  'smuaaa',
#  'kontl',
#  'saking',
#  'ngejudge',
#  'gua',
#  'hahahaaa',
#  'ngepress',
#  'kmk',
#  'njirr',
#  'upgrades',
#  'menghargai',
#  'lino',
#  'aduhhhh',
#  'rctikak',
#  'duaaa',
#  'pdhal',
#  'kapala',
#  'line',
#  'lh',
#  'bersama',
#  'dikubu',
#  'ny',
#  'corettt',
#  'mnit',
#  'allahklo',
#  'shif',
#  'ngantongin',
#  'styout',
#  'eekgiliran',
#  'kasihh',
#  'ngantuk',
#  'indonesirs',
#  'gen',
#  'jngn',
#  'woii',
#  'jamuan',
#  'benar',
#  'asmawi',
#  'asu',
#  'anjayylagi',
#  'kalah',
#  'menepi',
#  'pencipta',
#  'lawan',
#  'hilgres',
#  'menit',
#  'tulisannya',
#  'bertanding',
#  'yaitu',
#  'onyou',
#  'ma',
#  'kluar',
#  'out',
#  'rendah',
#  'item',
#  'strickercoach',
#  'evaluasi',
#  'geser',
#  'wasitnya',
#  'ji',
#  'report',
#  'umur',
#  'bebeh',
#  'meh',
#  'baper',
#  'kecelakaan',
#  'perpanjangan',
#  'sesakit',
#  'results',
#  'sumpahin',
#  'lihatlah',
#  'kalinya',
#  'kalahtimnas',
#  'tanem',
#  'maapsalah',
#  'semoga',
#  'bah',
#  'ditengah',
#  'amiiin',
#  'kemungkinan',
#  'segitu',
#  'strong',
#  'hhaha',
#  'backkk',
#  'lari',
#  'pntes',
#  'dua',
#  'dikasih',
#  'dimainin',
#  'video',
#  'berpihak',
#  'lebih',
#  'logis',
#  'captain',
#  'aman',
#  'garnacho',
#  'ancene',
#  'cokkkkkkjfdsssz',
#  'tolkon',
#  'ringan',
#  'udahh',
#  'mabok',
#  'anng',
#  'males',
#  'bkl',
#  'dibutuhkan',
#  'tali',
#  'naturalisasi',
#  'ramaikan',
#  'emamg',
#  'mainnnnn',
#  'ndak',
#  'atuh',
#  'alah',
#  'jirr',
#  'sampaisampai',
#  'babu',
#  'haaa',
#  'adanya',
#  'menunjukan',
#  'nurul',
#  'gblk',
#  'gawang',
#  'memek',
#  'sihh',
#  'eksperimen',
#  'cari',
#  'sudah',
#  'makanya',
#  'paan',
#  'diulang',
#  'khianati',
#  'cabang',
#  'pastiii',
#  'risaldii',
#  'positif',
#  'sii',
#  'klw',
#  'gatau',
#  'bocil',
#  'mengalahkan',
#  'vt',
#  'bulan',
#  'kuuuu',
#  'gasuka',
#  'lagiidi',
#  'komentar',
#  'lempar',
#  'thohir',
#  'solo',
#  'macem',
#  'struik',
#  'gasskeun',
#  'trnyata',
#  'arhan',
#  'cakap',
#  'sebenarnya',
#  'wedih',
#  'amanwasit',
#  'gregetan',
#  'jaga',
#  'hewan',
#  'martin',
#  'kedapan',
#  'temen',
#  'sakitbuang',
#  'enggan',
#  'dipanggil',
#  'dont',
#  'nyadar',
#  'federasi',
#  'sinyalnya',
#  'lebar',
#  'sini',
#  'matchday',
#  'melu',
#  'fairrr',
#  'semangatt',
#  'piroe',
#  'ak',
#  'musuh',
#  'tolol',
#  '_',
#  'garudakuu',
#  'and',
#  'wargaaa',
#  'keluar',
#  'tandai',
#  'trima',
#  'bertindak',
#  'dlu',
#  'agar',
#  'lawat',
#  'tamu',
#  'akal',
#  'dn',
#  'terbukti',
#  'tuan',
#  'pelapisklu',
#  'bocah',
#  'diposisi',
#  'nyobalgi',
#  'them',
#  'ajirr',
#  'ta',
#  'kopok',
#  'klah',
#  'sistem',
#  'ajarizky',
#  'terobosan',
#  'kurangin',
#  'tangkep',
#  'lot',
#  'tapibeban',
#  'mentok',
#  'sudahlahh',
#  'gredak',
#  'bild',
#  'lgi',
#  'buzzer',
#  'erling',
#  'prit',
#  'taukan',
#  'sembuh',
#  'yooo',
#  'kedepannya',
#  'hrusnya',
#  'kebobolan',
#  'comeback',
#  'ridho',
#  'bangt',
#  'momen',
#  'fiks',
#  'kontolll',
#  'anjjj',
#  'kemaren',
#  'okay',
#  'mafia',
#  'diapain',
#  'gianni',
#  'kaya',
#  'afctimurtengah',
#  'dadi',
#  'tdr',
#  'botakburiq',
#  'pas',
#  'spill',
#  'sumpahi',
#  'ngadu',
#  'aminayo',
#  'wajar',
#  'maaf',
#  'bakal',
#  'young',
#  'luka',
#  'firiwit',
#  'iniii',
#  'superstars',
#  'didukung',
#  'mie',
#  'sementara',
#  'brutalll',
#  'kakek',
#  'timtam',
#  'lcb',
#  'guendeng',
#  'iyooo',
#  'gwila',
#  'berangkat',
#  'soal',
#  'nyaaa',
#  'pernah',
#  'bbak',
#  'cuman',
#  'myamain',
#  'tenan',
#  'saja',
#  'let',
#  'janokkkkkk',
#  'chinaa',
#  'ig',
#  'caranya',
#  'ancen',
#  'prefer',
#  'bismillah',
#  'dipuji',
#  'ngimpi',
#  'kbnykan',
#  'cairnya',
#  'lwan',
#  'satu',
#  'tbahanny',
#  'dikira',
#  'nnt',
#  'pleaaase',
#  'ora',
#  'gede',
#  'biasalah',
#  'kebelakang',
#  'dibawa',
#  'bayaran',
#  'arya',
#  'lainnyasehingga',
#  'kga',
#  'kerja',
#  'senam',
#  'guyswaktu',
#  'nyalakan',
#  'anying',
#  'apasih',
#  'butuh',
#  'aqu',
#  'capee',
#  'kenapandi',
#  'berusaha',
#  'lineup',
#  'ayok',
#  'ekekkek',
#  'taaakkk',
#  'mimpin',
#  'fans',
#  'pertahankan',
#  'anjggg',
#  'jatoh',
#  'lembek',
#  'sepakat',
#  'laper',
#  'klau',
#  'it',
#  'pokeh',
#  'pihak',
#  'ngimbangin',
#  'aq',
#  'siksa',
#  'hallahhhh',
#  'mnde',
#  'iyyyaaa',
#  'outgoal',
#  'gbk',
#  'qobuli',
#  'tetap',
#  'delai',
#  'saya',
#  'nyamperin',
#  'kecil',
#  'dlm',
#  'manejer',
#  'masalahmah',
#  'moon',
#  'mainmungkin',
#  'wasitt',
#  'kutuk',
#  'gituu',
#  'mmbuktikan',
#  'ngeselin',
#  'timnas',
#  'tuhkocak',
#  'bisaaa',
#  'entah',
#  'put',
#  'can',
#  'give',
#  'kedepan',
#  'pepkpuqikntilireng',
#  'negatif',
#  'nyapo',
#  'dri',
#  'waktunyatv',
#  'asnawijahat',
#  'abisss',
#  'menurut',
#  'gagal',
#  'ouh',
#  'biadab',
#  'lolot',
#  'please',
#  'coyg',
#  'pasar',
#  'aaja',
#  'teman',
#  'edan',
#  'time',
#  'mfthyang',
#  'kasar',
#  'ehh',
#  'diorang',
#  'penjuru',
#  'tegak',
#  'dipangil',
#  'hoky',
#  'slotnya',
#  'bisanya',
#  'ketebak',
#  'ngegolin',
#  'jo',
#  'mainen',
#  'journey',
#  'kobisa',
#  'lets',
#  'gabakalan',
#  'nahan',
#  'ntin',
#  'muluu',
#  'langganan',
#  'berat',
#  'akhir',
#  'nonaktifkan',
#  'dark',
#  'sloww',
#  'nyah',
#  'past',
#  'dikir',
#  'sll',
#  'iq',
#  'botolbotak',
#  'kluargaaa',
#  'disenggol',
#  'kipernya',
#  'ahmedalkaf_official',
#  'dagdigdurser',
#  'yakarna',
#  'job',
#  'nya',
#  'us',
#  'anjir',
#  'verdong',
#  'kelemahan',
#  'terburuk',
#  'bolela',
#  'ramalan',
#  'air',
#  'ngdumelin',
#  'depannya',
#  'nagapain',
#  'kejar',
#  'rombongan',
#  'sy',
#  'kanca',
#  'wlwlwkwk',
#  'sebelas',
#  'dikitkaki',
#  'ngak',
#  'riski',
#  'babimakanya',
#  'mainnya',
#  'panjang',
#  'menganggap',
#  'terjadiharusnya',
#  'a',
#  'match',
#  'sejati',
#  'bolanya',
#  'niat',
#  'usut',
#  'sajung',
#  'bijak',
#  'pandang',
#  'mampus',
#  'fifaa',
#  'bkn',
#  'gimanawaktu',
#  'sekil',
#  'muhammadaamiin',
#  'terbesar',
#  'iyah',
#  'anjggggh',
#  'cadangan',
#  'telp',
#  'maarten',
#  'gilakkkk',
#  'blunder',
#  'g',
#  'private',
#  'monyet',
#  'strategi',
#  'bahrainlangsung',
#  'suggest',
#  'poll',
#  'panas',
#  'ngerasa',
#  'matematika',
#  'pelatih',
#  'maka',
#  'sinulingga',
#  'hitamdongobotakgak',
#  'pantang',
#  'anjay',
#  'cod',
#  'bangun',
#  'pembawa',
#  'mn',
#  'nantinya',
#  'dipksain',
#  'smpedibuat',
#  'goblokkkkk',
#  'jordy',
#  'berharap',
#  'tenang',
#  'pengen',
#  'kenp',
#  'utk',
#  'selalu',
#  'experimen',
#  'betol',
#  'waktutaktik',
#  'tidur',
#  'muka',
#  'tdak',
#  'in',
#  'mudahan',
#  'hallobenks',
#  'istrix',
#  'beh',
#  'pripat',
#  'ngedukung',
#  'pgn',
#  'ajh',
#  'udaaa',
#  'semua',
#  'well',
#  'wahyudimas',
#  'pertandinganya',
#  'salahin',
#  'wis',
#  'mlu',
#  'harusy',
#  'cmat',
#  'salahkan',
#  'cadangin',
#  'persaingan',
#  'yasemangat',
#  'hbissancoba',
#  'ygy',
#  'kesalahan',
#  'besar',
#  'jimat',
#  'pikri',
#  'dipakai',
#  'mengingat',
#  'anak',
#  'filing',
#  'support',
#  'rojan',
#  'indog',
#  'plontos',
#  'jogja',
#  'woyy',
#  'panti',
#  'indonesiaku',
#  'ahmadalkaf',
#  'amat',
#  'c',
#  'tkdir',
#  'hrs',
#  'sama',
#  'keluarkan',
#  'postingansty',
#  'stating',
#  'kaalu',
#  'akan',
#  'kontol',
#  'belandanya',
#  'kambuaya',
#  'krena',
#  'confident',
#  'wakk',
#  'menangkalo',
#  'bgsumpah',
#  'itung',
#  'pasti',
#  'jngan',
#  'berguna',
#  'tumor',
#  'gantiin',
#  'mknya',
#  'perjuangan',
#  'tapii',
#  'bole',
#  'mikir',
#  'meninggal',
#  'kacau',
#  'lahnoh',
#  'stay',
#  'cobacoba',
#  'asnawi',
#  'biang',
#  'tandain',
#  'coach',
#  'b',
#  'kartu',
#  'kadang',
#  'sanggup',
#  'join',
#  'cupu',
#  'math',
#  'trs',
#  'ad',
#  'bulanan',
#  'menutupi',
#  'pembenci',
#  'mustahil',
#  'lsg',
#  'trueeee',
#  ...]
